# %% [markdown]
# <h1>Machine Learning

# %% [markdown]
# En este notebook se realizaran las transformaciones correspondientes al modelo de recomendación utilizando similitud de coseno. La similitud de coseno es una medida utilizada en machine learning para evaluar la similitud entre dos vectores. Es especialmente común en problemas relacionados con el procesamiento del lenguaje natural (NLP) y la recuperación de información.

# %% [markdown]
# <h2>Importaciones

# %%
import pandas as pd
import numpy as np
import scipy as sp
from sklearn.metrics.pairwise import cosine_similarity
import pyarrow as pa
import pyarrow.parquet as pq

# %% [markdown]
# Se cargan los datos y se crea el dataframe correspondiente.

# %%
machineLearningDf = pd.read_parquet('../data/machineLearning.parquet')

# %%
machineLearningDf.head()
# Out:
# app_name      ! That Bastard Is Trying To Steal Our Gold !  \
# user_id
# --000--                                                NaN
# --ace--                                                NaN
# --ionex--                                              NaN
# -2SV-vuLB-Kg                                           NaN
# -Azsael-                                               NaN
#
# app_name      //N.P.P.D. RUSH//- The milk of Ultraviolet  0RBITALIS  \
# user_id
# --000--                                              NaN        NaN
# --ace--                                              NaN        NaN
# --ionex--                                            NaN        NaN
# -2SV-vuLB-Kg                                         NaN        NaN
# -Azsael-                                             NaN        NaN
#
# app_name      10,000,000  100% Orange Juice  \
# user_id
# --000--              NaN                NaN
# --ace--              NaN                NaN
# --ionex--            NaN                NaN
# -2SV-vuLB-Kg         NaN                NaN
# -Azsael-             NaN                NaN
#
# app_name      100% Orange Juice - Krila & Kae Character Pack  1001 Spikes  \
# user_id
# --000--                                                  NaN          NaN
# --ace--                                                  NaN          NaN
# --ionex--                                                NaN          NaN
# -2SV-vuLB-Kg                                             NaN          NaN
# -Azsael-                                                 NaN          NaN
#
# app_name      12 Labours of Hercules  \
# user_id
# --000--                          NaN
# --ace--                          NaN
# --ionex--                        NaN
# -2SV-vuLB-Kg                     NaN
# -Azsael-                         NaN
#
# app_name      12 Labours of Hercules II: The Cretan Bull  12 is Better Than 6  \
# user_id
# --000--                                              NaN                  NaN
# --ace--                                              NaN                  NaN
# --ionex--                                            NaN                  NaN
# -2SV-vuLB-Kg                                         NaN                  NaN
# -Azsael-                                             NaN                  NaN
#
# app_name      ...  nail'd  oO  planetarian ~the reverie of a little planet~  \
# user_id       ...
# --000--       ...     NaN NaN                                           NaN
# --ace--       ...     NaN NaN                                           NaN
# --ionex--     ...     NaN NaN                                           NaN
# -2SV-vuLB-Kg  ...     NaN NaN                                           NaN
# -Azsael-      ...     NaN NaN                                           NaN
#
# app_name      resident evil 4 / biohazard 4  sZone-Online  \
# user_id
# --000--                                 NaN           NaN
# --ace--                                 NaN           NaN
# --ionex--                               NaN           NaN
# -2SV-vuLB-Kg                            NaN           NaN
# -Azsael-                                NaN           NaN
#
# app_name      the static speaks my name  theBlu  theHunter Classic  \
# user_id
# --000--                             NaN     NaN                NaN
# --ace--                             NaN     NaN                NaN
# --ionex--                           NaN     NaN                NaN
# -2SV-vuLB-Kg                        NaN     NaN                NaN
# -Azsael-                            NaN     NaN                NaN
#
# app_name      theHunter: Primal  Астролорды: Облако Оорта
# user_id
# --000--                     NaN                       NaN
# --ace--                     NaN                       NaN
# --ionex--                   NaN                       NaN
# -2SV-vuLB-Kg                NaN                       NaN
# -Azsael-                    NaN                       NaN
#
# [5 rows x 3195 columns]

# %% [markdown]
# Se normalizan los valores del dataframe restando la media de las calificaciones de cada usuario y dividiendo el resultado por la diferencia entre el valor máximo y mínimo de las calificaciones. Esto centra las calificaciones de cada usuario en cero y las escala según su variabilidad. Durante este proceso se eliminan los usuarios que han otorgado únicamente una calificación o han evaluado todos los juegos de la misma manera.

# %%
machineLearningDf = machineLearningDf.apply(lambda x: (x-np.mean(x))/(np.max(x)-np.min(x)), axis=1)
machineLearningDf = machineLearningDf.fillna(0)
machineLearningDf = machineLearningDf.T
machineLearningDf = machineLearningDf.loc[:, (machineLearningDf != 0).any(axis=0)]
machineLearningDf
# Out:
# user_id                                       -2SV-vuLB-Kg  -PRoSlayeR-  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !           0.0          0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet             0.0          0.0
# 0RBITALIS                                              0.0          0.0
# 10,000,000                                             0.0          0.0
# 100% Orange Juice                                      0.0          0.0
# ...                                                    ...          ...
# the static speaks my name                              0.0          0.0
# theBlu                                                 0.0          0.0
# theHunter Classic                                      0.0          0.0
# theHunter: Primal                                      0.0          0.0
# Астролорды: Облако Оорта                               0.0          0.0
#
# user_id                                       -SEVEN-  -_PussyDestroyer_-  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !      0.0                 0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet        0.0                 0.0
# 0RBITALIS                                         0.0                 0.0
# 10,000,000                                        0.0                 0.0
# 100% Orange Juice                                 0.0                 0.0
# ...                                               ...                 ...
# the static speaks my name                         0.0                 0.0
# theBlu                                            0.0                 0.0
# theHunter Classic                                 0.0                 0.0
# theHunter: Primal                                 0.0                 0.0
# Астролорды: Облако Оорта                          0.0                 0.0
#
# user_id                                       0-3-0  00000000000000000001227  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !    0.0                      0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet      0.0                      0.0
# 0RBITALIS                                       0.0                      0.0
# 10,000,000                                      0.0                      0.0
# 100% Orange Juice                               0.0                      0.0
# ...                                             ...                      ...
# the static speaks my name                       0.0                      0.0
# theBlu                                          0.0                      0.0
# theHunter Classic                               0.0                      0.0
# theHunter: Primal                               0.0                      0.0
# Астролорды: Облако Оорта                        0.0                      0.0
#
# user_id                                       00454211432342  00True  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !             0.0     0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet               0.0     0.0
# 0RBITALIS                                                0.0     0.0
# 10,000,000                                               0.0     0.0
# 100% Orange Juice                                        0.0     0.0
# ...                                                      ...     ...
# the static speaks my name                                0.0     0.0
# theBlu                                                   0.0     0.0
# theHunter Classic                                        0.0     0.0
# theHunter: Primal                                        0.0     0.0
# Астролорды: Облако Оорта                                 0.0     0.0
#
# user_id                                       01189958889189157253  04061993  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !                   0.0       0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet                     0.0       0.0
# 0RBITALIS                                                      0.0       0.0
# 10,000,000                                                     0.0       0.0
# 100% Orange Juice                                              0.0       0.0
# ...                                                            ...       ...
# the static speaks my name                                      0.0       0.0
# theBlu                                                         0.0       0.0
# theHunter Classic                                              0.0       0.0
# theHunter: Primal                                              0.0       0.0
# Астролорды: Облако Оорта                                       0.0       0.0
#
# user_id                                       ...  zombieskiler6969  zomgieee  \
# app_name                                      ...
# ! That Bastard Is Trying To Steal Our Gold !  ...               0.0       0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet    ...               0.0       0.0
# 0RBITALIS                                     ...               0.0       0.0
# 10,000,000                                    ...               0.0       0.0
# 100% Orange Juice                             ...               0.0       0.0
# ...                                           ...               ...       ...
# the static speaks my name                     ...               0.0       0.0
# theBlu                                        ...               0.0       0.0
# theHunter Classic                             ...               0.0       0.0
# theHunter: Primal                             ...               0.0       0.0
# Астролорды: Облако Оорта                      ...               0.0       0.0
#
# user_id                                       zoozles  zp3413  zrustz16  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !      0.0     0.0       0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet        0.0     0.0       0.0
# 0RBITALIS                                         0.0     0.0       0.0
# 10,000,000                                        0.0     0.0       0.0
# 100% Orange Juice                                 0.0     0.0       0.0
# ...                                               ...     ...       ...
# the static speaks my name                         0.0     0.0       0.0
# theBlu                                            0.0     0.0       0.0
# theHunter Classic                                 0.0     0.0       0.0
# theHunter: Primal                                 0.0     0.0       0.0
# Астролорды: Облако Оорта                          0.0     0.0       0.0
#
# user_id                                       zsharoarkbr  zucchin1  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !          0.0       0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet            0.0       0.0
# 0RBITALIS                                             0.0       0.0
# 10,000,000                                            0.0       0.0
# 100% Orange Juice                                     0.0       0.0
# ...                                                   ...       ...
# the static speaks my name                             0.0       0.0
# theBlu                                                0.0       0.0
# theHunter Classic                                     0.0       0.0
# theHunter: Primal                                     0.0       0.0
# Астролорды: Облако Оорта                              0.0       0.0
#
# user_id                                       zuzuga2003  zv_odd  zyr0n1c
# app_name
# ! That Bastard Is Trying To Steal Our Gold !    0.000000     0.0      0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet      0.000000     0.0      0.0
# 0RBITALIS                                       0.000000     0.0      0.0
# 10,000,000                                      0.000000     0.0      0.0
# 100% Orange Juice                               0.000000     0.0      0.0
# ...                                                  ...     ...      ...
# the static speaks my name                       0.000000     0.0      0.0
# theBlu                                          0.000000     0.0      0.0
# theHunter Classic                              -0.666667     0.0      0.0
# theHunter: Primal                               0.000000     0.0      0.0
# Астролорды: Облако Оорта                        0.000000     0.0      0.0
#
# [3195 rows x 7368 columns]

# %% [markdown]
# Convertimos la matriz a formato de matriz dispersa que guarda solo los valores distintos a 0 para reducir la memoria utilizada y mejorar la eficiencia.

# %%
machineLearningSparseDf = sp.sparse.csr_matrix(machineLearningDf.values)
machineLearningSparseDf
# Out:
# <3195x7368 sparse matrix of type '<class 'numpy.float64'>'
# 	with 29040 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Se crea la matriz de similitud utilizando coseno inverso. Esto evalúa la similitud entre dos vectores en un espacio multidimensional. Para efectos de este modelo, nos permite determinar que tan similares son dos juegos basado en las recomendaciones de los usuarios.

# %%
itemSimilarity = cosine_similarity(machineLearningSparseDf)

# %%
itemSimDf = pd.DataFrame(itemSimilarity, index = machineLearningDf.index, columns = machineLearningDf.index)

# %%
itemSimDf.head()
# Out:
# app_name                                      ! That Bastard Is Trying To Steal Our Gold !  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !                                           1.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet                                             0.0
# 0RBITALIS                                                                              0.0
# 10,000,000                                                                             0.0
# 100% Orange Juice                                                                      0.0
#
# app_name                                      //N.P.P.D. RUSH//- The milk of Ultraviolet  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !                                         0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet                                           1.0
# 0RBITALIS                                                                            0.0
# 10,000,000                                                                           0.0
# 100% Orange Juice                                                                    0.0
#
# app_name                                      0RBITALIS  10,000,000  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !        0.0         0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet          0.0         0.0
# 0RBITALIS                                           1.0         0.0
# 10,000,000                                          0.0         1.0
# 100% Orange Juice                                   0.0         0.0
#
# app_name                                      100% Orange Juice  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !                0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet                  0.0
# 0RBITALIS                                                   0.0
# 10,000,000                                                  0.0
# 100% Orange Juice                                           1.0
#
# app_name                                      100% Orange Juice - Krila & Kae Character Pack  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !                                             0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet                                               0.0
# 0RBITALIS                                                                                0.0
# 10,000,000                                                                               0.0
# 100% Orange Juice                                                                        0.0
#
# app_name                                      1001 Spikes  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !          0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet            0.0
# 0RBITALIS                                             0.0
# 10,000,000                                            0.0
# 100% Orange Juice                                     0.0
#
# app_name                                      12 Labours of Hercules  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !                     0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet                       0.0
# 0RBITALIS                                                        0.0
# 10,000,000                                                       0.0
# 100% Orange Juice                                                0.0
#
# app_name                                      12 Labours of Hercules II: The Cretan Bull  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !                                         0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet                                           0.0
# 0RBITALIS                                                                            0.0
# 10,000,000                                                                           0.0
# 100% Orange Juice                                                                    0.0
#
# app_name                                      12 is Better Than 6  ...  \
# app_name                                                           ...
# ! That Bastard Is Trying To Steal Our Gold !                  0.0  ...
# //N.P.P.D. RUSH//- The milk of Ultraviolet                    0.0  ...
# 0RBITALIS                                                     0.0  ...
# 10,000,000                                                    0.0  ...
# 100% Orange Juice                                             0.0  ...
#
# app_name                                      nail'd   oO  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !     0.0  0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet       0.0  0.0
# 0RBITALIS                                        0.0  0.0
# 10,000,000                                       0.0  0.0
# 100% Orange Juice                                0.0  0.0
#
# app_name                                      planetarian ~the reverie of a little planet~  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !                                           0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet                                             0.0
# 0RBITALIS                                                                              0.0
# 10,000,000                                                                             0.0
# 100% Orange Juice                                                                      0.0
#
# app_name                                      resident evil 4 / biohazard 4  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !                            0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet                              0.0
# 0RBITALIS                                                               0.0
# 10,000,000                                                              0.0
# 100% Orange Juice                                                       0.0
#
# app_name                                      sZone-Online  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !           0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet             0.0
# 0RBITALIS                                              0.0
# 10,000,000                                             0.0
# 100% Orange Juice                                      0.0
#
# app_name                                      the static speaks my name  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !                  -0.371768
# //N.P.P.D. RUSH//- The milk of Ultraviolet                     0.000000
# 0RBITALIS                                                      0.000000
# 10,000,000                                                     0.000000
# 100% Orange Juice                                              0.000000
#
# app_name                                      theBlu  theHunter Classic  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !     0.0                0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet       0.0                0.0
# 0RBITALIS                                        0.0                0.0
# 10,000,000                                       0.0                0.0
# 100% Orange Juice                                0.0                0.0
#
# app_name                                      theHunter: Primal  \
# app_name
# ! That Bastard Is Trying To Steal Our Gold !                0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet                  0.0
# 0RBITALIS                                                   0.0
# 10,000,000                                                  0.0
# 100% Orange Juice                                           0.0
#
# app_name                                      Астролорды: Облако Оорта
# app_name
# ! That Bastard Is Trying To Steal Our Gold !                       0.0
# //N.P.P.D. RUSH//- The milk of Ultraviolet                         0.0
# 0RBITALIS                                                          0.0
# 10,000,000                                                         0.0
# 100% Orange Juice                                                  0.0
#
# [5 rows x 3195 columns]

# %% [markdown]
# Finalizadas las transformaciones podemos guardar como parquet.

# %%
itemSimDf.to_parquet('../data/itemSim.parquet')

# %% [markdown]
# Dada la comprensión de las relaciones entre los distintos juegos, se desarrolla un código que realice recomendaciones basadas en la similitud del coseno. Se toma como input el nombre de un juego, ordena de manera descendente la columna correspondiente a ese juego en la matriz de similitud entre elementos (item_sim_df), asegurando que los juegos más similares ocupen las primeras filas. Luego, selecciona los 5 juegos más similares (excluyendo el juego de entrada), y genera una lista de juegos similares al juego especificado. La función correspondiente a este código se puede encontrar en el Notebook [Funciones_API](https://github.com/JBSosa/MLOps-Steam/blob/main/Notebooks/Funciones_API.ipynb).
